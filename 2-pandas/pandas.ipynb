# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.shape
# Out:
# (5,)

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.name = "calories"

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: calories, dtype: int64

# %%
s[1:3]
# Out:
# 1    2
# 2    3
# Name: calories, dtype: int64
